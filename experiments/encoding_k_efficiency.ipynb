# %%
import util.bit_stream as bs
from tree import tree, encoding
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
# Auto-correlation with lag 1
def gen_signal(length, auto_correlation):
    assert 0 <= auto_correlation <= 1
    assert length > 0
    first_bit = random.randint(0, 1)
    signal = np.zeros(length, dtype=int)
    signal[0] = first_bit
    for i in range(1,length):
        signal[i] = signal[i-1] if random.random() < auto_correlation else 1-signal[i-1]

    return signal

def data_point(signal, k):
    ts = np.array([encoding.bits_to_tree_k(bs.bit_stream_literal(signal), k) for k in ks])
    return ts

# %%
import plotly.graph_objects as go
import pandas as pd
from tree.encoding import bits_to_tree_k  as btt_k 

ks = [3,5,9,17,33,65]
signal_lengths = [l for l in range(500,5000,500)]
tries_per_length = 20

signals = [gen_signal(l, 0.5) for l in signal_lengths for _ in range(tries_per_length)]

gen_tree = lambda sig, k : encoding.bits_to_tree_k(bs.bit_stream_literal(sig), k)
data = [[len(signal), k, gen_tree(signal, k).n_descendants] 
            for signal in signals 
            for k in ks]
df = pd.DataFrame(data, columns=['Bits', 'k', 'Nodes']) 
df
# Out:
#       Bits   k  nodes
# 0      500   3    266
# 1      500   5    307
# 2      500   9    414
# 3      500  17    695
# 4      500  33   1128
# ...    ...  ..    ...
# 1075  4500   5   2607
# 1076  4500   9   3655
# 1077  4500  17   5535
# 1078  4500  33   9292
# 1079  4500  65  15668
#
# [1080 rows x 3 columns]

# %%
import plotly.express as px

fig = px.box(df, x="Bits", y="Nodes", color="k")
fig.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default
fig.show()
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 import plotly.express as px
# ----> 3 fig = px.box(df, x="Bits", y="Nodes", color="k")
#       4 fig.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default
#       5 fig.show()
#
# File /opt/homebrew/lib/python3.11/site-packages/plotly/express/_chart_types.py:666, in box(data_frame, x, y, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, orientation, boxmode, log_x, log_y, range_x, range_y, points, notched, title, template, width, height)
#     625 def box(
#     626     data_frame=None,
#     627     x=None,
#    (...)
#     655     height=None,
#     656 ) -> go.Figure:
#     657     """
#     658     In a box plot, rows of `data_frame` are grouped together into a
#     659     box-and-whisker mark to visualize their distribution.
#    (...)
#     664     range (IQR: Q3-Q1), see "points" for other options.
#     665     """
# --> 666     return make_figure(
#     667         args=locals(),
#     668         constructor=go.Box,
#     669         trace_patch=dict(boxpoints=points, notched=notched, x0=" ", y0=" "),
#     670         layout_patch=dict(boxmode=boxmode),
#     671     )
#
# File /opt/homebrew/lib/python3.11/site-packages/plotly/express/_core.py:2076, in make_figure(args, constructor, trace_patch, layout_patch)
#    2073 layout_patch = layout_patch or {}
#    2074 apply_default_cascade(args)
# -> 2076 args = build_dataframe(args, constructor)
#    2077 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2078     args = process_dataframe_hierarchy(args)
#
# File /opt/homebrew/lib/python3.11/site-packages/plotly/express/_core.py:1485, in build_dataframe(args, constructor)
#    1482     args["color"] = None
#    1483 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1485 df_output, wide_id_vars = process_args_into_dataframe(
#    1486     args, wide_mode, var_name, value_name
#    1487 )
#    1489 # now that `df_output` exists and `args` contains only references, we complete
#    1490 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1491 # df_output
#    1493 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File /opt/homebrew/lib/python3.11/site-packages/plotly/express/_core.py:1210, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1208         if argument == "index":
#    1209             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1210         raise ValueError(err_msg)
#    1211 elif length and len(df_input[argument]) != length:
#    1212     raise ValueError(
#    1213         "All arguments should have the same length. "
#    1214         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1221         )
#    1222     )
#
# ValueError: Value of 'y' is not the name of a column in 'data_frame'. Expected one of ['Bits', 'k', 'nodes'] but received: Nodes
